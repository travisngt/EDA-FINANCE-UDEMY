# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import importlib
import missingno as msno

import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv (r"C:\Users\Admin\Downloads\udemy_output_All_Finance__Accounting_p1_p626.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13608 entries, 0 to 13607
# Data columns (total 20 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            13608 non-null  int64
#  1   title                         13608 non-null  object
#  2   url                           13608 non-null  object
#  3   is_paid                       13608 non-null  bool
#  4   num_subscribers               13608 non-null  int64
#  5   avg_rating                    13608 non-null  float64
#  6   avg_rating_recent             13608 non-null  float64
#  7   rating                        13608 non-null  float64
#  8   num_reviews                   13608 non-null  int64
#  9   is_wishlisted                 13608 non-null  bool
#  10  num_published_lectures        13608 non-null  int64
#  11  num_published_practice_tests  13608 non-null  int64
# ...

# %% [markdown]
# ## Statistics

# %%
mean_value = 455.0
df['discount_price__amount'].fillna(mean_value, inplace=True)
print(df['discount_price__amount'])
# Out:
# 0        455.0
# 1        455.0
# 2        455.0
# 3        455.0
# 4        455.0
#          ...
# 13603    455.0
# 13604    455.0
# 13605    455.0
# 13606    455.0
# 13607    455.0
# Name: discount_price__amount, Length: 13608, dtype: float64

# %%
statistics = df.describe().T

sorted_statistics = statistics.sort_values("mean",ascending=False)

styled_statistics = sorted_statistics.style.background_gradient(cmap="Greens")

styled_statistics = styled_statistics.bar(subset=["std"], color="blue")

styled_statistics = styled_statistics.bar(subset=["75%"], color="red")

styled_statistics
# Out:
# <style type="text/css">
# #T_3eb8f_row0_col0, #T_3eb8f_row0_col1, #T_3eb8f_row0_col3, #T_3eb8f_row0_col4, #T_3eb8f_row0_col5, #T_3eb8f_row0_col7, #T_3eb8f_row2_col0, #T_3eb8f_row3_col0, #T_3eb8f_row4_col0, #T_3eb8f_row5_col0, #T_3eb8f_row6_col0, #T_3eb8f_row7_col0, #T_3eb8f_row8_col0, #T_3eb8f_row9_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_3eb8f_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, blue 100.0%, transparent 100.0%);
# }
# #T_3eb8f_row0_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, red 100.0%, transparent 100.0%);
# }
# ...

# %%
for column in df.columns:
    print(f"{column} ---> {df[column].nunique()}")
# Out:
# id ---> 13608
# title ---> 13563
# url ---> 13608
# is_paid ---> 2
# num_subscribers ---> 4875
# avg_rating ---> 1965
# avg_rating_recent ---> 11781
# rating ---> 11781
# num_reviews ---> 1285
# is_wishlisted ---> 1
# num_published_lectures ---> 301
# num_published_practice_tests ---> 7
# created ---> 13607
# published_time ---> 13605
# discount_price__amount ---> 53
# discount_price__currency ---> 1
# discount_price__price_string ---> 53
# price_detail__amount ---> 37
# price_detail__currency ---> 1
# price_detail__price_string ---> 37

# %%
for column in df.columns :
  nan_values = df[column].isna().sum()
  print(f"The column {column} has {nan_values} NaN values. ")
# Out:
# The column id has 0 NaN values.
# The column title has 0 NaN values.
# The column url has 0 NaN values.
# The column is_paid has 0 NaN values.
# The column num_subscribers has 0 NaN values.
# The column avg_rating has 0 NaN values.
# The column avg_rating_recent has 0 NaN values.
# The column rating has 0 NaN values.
# The column num_reviews has 0 NaN values.
# The column is_wishlisted has 0 NaN values.
# The column num_published_lectures has 0 NaN values.
# The column num_published_practice_tests has 0 NaN values.
# The column created has 0 NaN values.
# The column published_time has 0 NaN values.
# The column discount_price__amount has 0 NaN values.
# The column discount_price__currency has 1403 NaN values.
# The column discount_price__price_string has 1403 NaN values.
# The column price_detail__amount has 497 NaN values.
# The column price_detail__currency has 497 NaN values.
# The column price_detail__price_string has 497 NaN values.

# %%
msno.heatmap(df)
# Out:
# <Axes: >
